# %% [markdown]
# # Recommender Systems

# %% [markdown]
# I'm going to be using some movie data from Wes's python for data analysis book
#
# It has over 1 million ratings of almost 4,000 movies from over 6,000 individual users
#
# you can get the movie data and other data from
#
# http://github.com/pydata/pydata-book
#
# or of course, you can just get it from my github repo as well

# %%
import pandas as pd
unames = ['user_id', 'gender', 'age', 'occupation', 'zip']
users = pd.read_table('movielens/users.dat', sep='::', header=None, names=unames)
rnames = ['user_id', 'movie_id', 'rating', 'timestamp']
ratings = pd.read_table('movielens/ratings.dat', sep='::', header=None, names=rnames)
mnames = ['movie_id', 'title', 'genres']
movies = pd.read_table('movielens/movies.dat', sep='::', header=None, names=mnames)
data = pd.merge(pd.merge(ratings, users), movies)
data.head()
# Out:
#    user_id  movie_id  rating  timestamp gender  age  occupation    zip  \
# 0        1      1193       5  978300760      F    1          10  48067
# 1        2      1193       5  978298413      M   56          16  70072
# 2       12      1193       4  978220179      M   25          12  32793
# 3       15      1193       4  978199279      M   25           7  22903
# 4       17      1193       5  978158471      M   50           1  95350
#
#                                     title genres
# 0  One Flew Over the Cuckoo's Nest (1975)  Drama
# 1  One Flew Over the Cuckoo's Nest (1975)  Drama
# 2  One Flew Over the Cuckoo's Nest (1975)  Drama
# 3  One Flew Over the Cuckoo's Nest (1975)  Drama
# 4  One Flew Over the Cuckoo's Nest (1975)  Drama
#
# [5 rows x 10 columns]

# %%
data.drop(['movie_id','timestamp','zip','genres'],axis= 1,inplace=True)
data.head()
# Out:
#    user_id  rating gender  age  occupation  \
# 0        1       5      F    1          10
# 1        2       5      M   56          16
# 2       12       4      M   25          12
# 3       15       4      M   25           7
# 4       17       5      M   50           1
#
#                                     title
# 0  One Flew Over the Cuckoo's Nest (1975)
# 1  One Flew Over the Cuckoo's Nest (1975)
# 2  One Flew Over the Cuckoo's Nest (1975)
# 3  One Flew Over the Cuckoo's Nest (1975)
# 4  One Flew Over the Cuckoo's Nest (1975)
#
# [5 rows x 6 columns]

# %%
mean_ratings = data.pivot_table('rating', rows='title',cols='age', aggfunc='mean')
ratings_by_title = data.groupby('title').size()
active_titles = ratings_by_title.index[ratings_by_title >= 250]
mean_ratings = mean_ratings.ix[active_titles]
top_ratings_35 = mean_ratings.sort_index(by=35, ascending=False)
top_ratings_35[:5]
# Out:
# age                                                                        1   \
# title
# Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)                        4.153846
# To Kill a Mockingbird (1962)                                         3.968750
# City Lights (1931)                                                   4.500000
# Godfather, The (1972)                                                4.471698
# Seven Samurai (The Magnificent Seven) (Shichinin no samurai) (1954)  4.500000
#
# age                                                                        18  \
# title
# Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)                        4.363636
# To Kill a Mockingbird (1962)                                         4.101351
# City Lights (1931)                                                   4.259259
# Godfather, The (1972)                                                4.505495
# Seven Samurai (The Magnificent Seven) (Shichinin no samurai) (1954)  4.604938
#
# age                                                                        25  \
# title
# Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)                        4.516556
# To Kill a Mockingbird (1962)                                         4.419014
# City Lights (1931)                                                   4.380952
# Godfather, The (1972)                                                4.574051
# Seven Samurai (The Magnificent Seven) (Shichinin no samurai) (1954)  4.549505
#
# age                                                                        35  \
# title
# Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)                        4.611570
# To Kill a Mockingbird (1962)                                         4.585859
# City Lights (1931)                                                   4.581818
# Godfather, The (1972)                                                4.541935
# Seven Samurai (The Magnificent Seven) (Shichinin no samurai) (1954)  4.532895
#
# age                                                                        45  \
# title
# Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)                        4.413793
# To Kill a Mockingbird (1962)                                         4.494949
# City Lights (1931)                                                   4.277778
# Godfather, The (1972)                                                4.357843
# Seven Samurai (The Magnificent Seven) (Shichinin no samurai) (1954)  4.541667
#
# age                                                                        50  \
# title
# Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)                        4.510204
# To Kill a Mockingbird (1962)                                         4.551020
# City Lights (1931)                                                   4.342105
# Godfather, The (1972)                                                4.540404
# Seven Samurai (The Magnificent Seven) (Shichinin no samurai) (1954)  4.657143
#
# age                                                                        56
# title
# Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)                        4.352941
# To Kill a Mockingbird (1962)                                         4.623188
# City Lights (1931)                                                   4.285714
# Godfather, The (1972)                                                4.467213
# Seven Samurai (The Magnificent Seven) (Shichinin no samurai) (1954)  4.513514
#
# [5 rows x 7 columns]

# %%
views_by_title = data.groupby('title').size()
views_by_title.sort(ascending= False)
views_by_title[0:40]
# Out:
# title
# American Beauty (1999)                                   3428
# Star Wars: Episode IV - A New Hope (1977)                2991
# Star Wars: Episode V - The Empire Strikes Back (1980)    2990
# Star Wars: Episode VI - Return of the Jedi (1983)        2883
# Jurassic Park (1993)                                     2672
# Saving Private Ryan (1998)                               2653
# Terminator 2: Judgment Day (1991)                        2649
# Matrix, The (1999)                                       2590
# Back to the Future (1985)                                2583
# Silence of the Lambs, The (1991)                         2578
# Men in Black (1997)                                      2538
# Raiders of the Lost Ark (1981)                           2514
# Fargo (1996)                                             2513
# Sixth Sense, The (1999)                                  2459
# Braveheart (1995)                                        2443
# Shakespeare in Love (1998)                               2369
# Princess Bride, The (1987)                               2318
# Schindler's List (1993)                                  2304
# L.A. Confidential (1997)                                 2288
# Groundhog Day (1993)                                     2278
# E.T. the Extra-Terrestrial (1982)                        2269
# Star Wars: Episode I - The Phantom Menace (1999)         2250
# Being John Malkovich (1999)                              2241
# Shawshank Redemption, The (1994)                         2227
# Godfather, The (1972)                                    2223
# Forrest Gump (1994)                                      2194
# Ghostbusters (1984)                                      2181
# Pulp Fiction (1994)                                      2171
# Terminator, The (1984)                                   2098
# Toy Story (1995)                                         2077
# Alien (1979)                                             2024
# Total Recall (1990)                                      1996
# Fugitive, The (1993)                                     1995
# Gladiator (2000)                                         1924
# Aliens (1986)                                            1820
# Blade Runner (1982)                                      1800
# Who Framed Roger Rabbit? (1988)                          1799
# Stand by Me (1986)                                       1785
# Usual Suspects, The (1995)                               1783
# Babe (1995)                                              1751
# dtype: int64

# %%
temp= data.pivot_table('rating', rows='title',cols='user_id')
filtered = temp[[5,8, 10, 15,17, 19,23]]
filtered.columns = [ 'alex','amy','bonnie','bob', 'celina',  'charlie','test']
filtered.drop(['amy','celina'], axis = 1, inplace = True)
filtered = filtered.ix[['Total Recall (1990)','Titanic (1997)','2001: A Space Odyssey (1968)','Stand by Me (1986)',
                    'American Beauty (1999)','Gladiator (2000)', 'Saving Private Ryan (1998)','Shakespeare in Love (1998)',
                    'Men in Black (1997)', 'L.A. Confidential (1997)', 'Babe (1995)','Matrix, The (1999)']]

"""filtered = filtered.ix[['Stand by Me (1986)', 'American Beauty (1999)','Babe (1995)','Braveheart (1995)',\
              'Shakespeare in Love (1998)','Princess Bride, The (1987)','Total Recall (1990)',\
              'Gladiator (2000)','2001: A Space Odyssey (1968)','Titanic (1997)',\
              'Saving Private Ryan (1998)',\
              'Terminator 2: Judgment Day (1991)','Matrix, The (1999)','Back to the Future (1985)',\
              'Silence of the Lambs, The (1991)','Men in Black (1997)','Raiders of the Lost Ark (1981)',\
              'Fargo (1996)','Sixth Sense, The (1999)','L.A. Confidential (1997)']]"""

scrubbed = filtered - filtered.mean()
scrubbed
# Out:
#                                   alex  bonnie   bob   charlie      test
# Total Recall (1990)          -1.888889     NaN  0.25       NaN  1.666667
# Titanic (1997)               -1.888889   -0.75   NaN       NaN       NaN
# 2001: A Space Odyssey (1968)       NaN   -0.75   NaN       NaN -1.333333
# Stand by Me (1986)                 NaN   -0.75   NaN -0.166667       NaN
# American Beauty (1999)        1.111111   -0.75  0.25  0.833333  0.666667
# Gladiator (2000)             -0.888889     NaN  1.25       NaN  0.666667
# Saving Private Ryan (1998)   -0.888889     NaN  0.25 -0.166667       NaN
# Shakespeare in Love (1998)         NaN    1.25  0.25       NaN -0.333333
# Men in Black (1997)           1.111111    1.25 -1.75  0.833333  0.666667
# L.A. Confidential (1997)      0.111111   -0.75 -0.75       NaN -1.333333
# Babe (1995)                   1.111111     NaN   NaN -1.166667 -0.333333
# Matrix, The (1999)            2.111111    1.25  0.25 -0.166667 -0.333333
#
# [12 rows x 5 columns]

# %%
x_1 = array([0.7,0.2,0.9,0.1,0.1,0.5,0.5,0.1,0.8,0.2,0.7,0.9])
x_2 = array([0.2,0.8,0.1,0.8,0.9,0.7,0.8,0.9,0.3,0.3,0.9,0.3])
x_0 = ones(len(x_2))
x = asarray([x_0,x_1,x_2])
theta_one = array([0.1,2,-1])
theta_two = array([0,-2,2])
print dot (theta_one, x)
print dot (theta_two, x)
# Out:
# [ 1.3 -0.3  1.8 -0.5 -0.6  0.4  0.3 -0.6  1.4  0.2  0.6  1.6]
# [-1.   1.2 -1.6  1.4  1.6  0.4  0.6  1.6 -1.   0.2  0.4 -1.2]

# %% [markdown]
# For each user $j$, learn a parameter $\theta^{(j)}$. Predict user $j$ as rating movie $i$ with $(\theta^{(j)})^Tx^{(i)} $
#
# $r(i,j) = 1$ if user j has rated movie $i$, otherwise 0
#
# $y^{(i,j)} = $ rating by user $j$ of movie $i$ if $r(i,j) = 1$
#
# $\theta^{(j)} = $ parameter vector for user $j$
#
# $x^{(i)} = $ feature vector of movie $i$
#
# $m^{(j)} = $ number of movies rated by user $j$
#
# To learn $\theta$ :
#
# $$\min\limits_{\theta^{(1)},...,\theta^{(n_u)}} ~~~\frac 1 {2} \sum\limits_{j = 1}^{n_u} \sum\limits_{i:r(i,j) = 1} \left((\theta^{(j)})^Tx^{(i)} - y^{(i,j)}\right)^2 +\frac {\lambda} {2} \sum\limits_{j = 1}^{n_u} \sum\limits_{k=1}^n(\theta_k^{(j)})^2$$

# %% [markdown]
# #### Gradient descent Update:

# %% [markdown]
# $\theta_k^{(j)} := \theta_k^{(j)} - \alpha \sum\limits_{i:r(i,j) = 1} ((\theta^{(j)})^Tx^{(i)}- y^{(i,j)})x_k^{(i)}~~~$       (for $k=0)$
#
# $\theta_k^{(j)} := \theta_k^{(j)} - \alpha \left(\sum\limits_{i:r(i,j) = 1} ((\theta^{(j)})^Tx^{(i)}- y^{(i,j)})x_k^{(i)} +\lambda\theta_k^{(j)} \right)~~~$       (for $k>0)$

# %%
a = scrubbed['alex']
x = pd.DataFrame(x)

zee = dot(theta_one,x.T)
print zee
print zee[a.notnull().values]
print x[a.notnull().values]
# Out:
# [ 1.3 -0.3  1.8 -0.5 -0.6  0.4  0.3 -0.6  1.4  0.2  0.6  1.6]
# [ 1.3 -0.3 -0.6  0.4  0.3  1.4  0.2  0.6  1.6]
#     0    1    2
# 0   1  0.7  0.2
# 1   1  0.2  0.8
# 4   1  0.1  0.9
# 5   1  0.5  0.7
# 6   1  0.5  0.8
# 8   1  0.8  0.3
# 9   1  0.2  0.3
# 10  1  0.7  0.9
# 11  1  0.9  0.3
#
# [9 rows x 3 columns]
